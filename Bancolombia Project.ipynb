# %%
#importing packages
import numpy as np
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
import scipy.optimize as spop
import matplotlib.pyplot as plt

# %%
#specifying parameters
stocks = ['BCOLOMBIA.CL','PFBCOLOM.CL']
start = '2008-2-4'
end = '2023-2-24'
fee = 0.0025
window = 252
t_threshold = -5
#retrieving data
data = pd.DataFrame()
slippage = pd.DataFrame()
execution = pd.DataFrame()

for stock in stocks:
    prices = yf.download(stock, start, end)
    data[stock] = prices['Close']
    slippage[stock] = ((((prices['Close']+prices['Open']+prices['High']+prices['Low'])/4)-prices['Open'])/prices['Open'])/4
    execution[stock] = prices['Open']
data = data.dropna()
slippage = slippage.dropna()
execution = execution.dropna()
data = data.drop('2020-03-09')
slippage = slippage.drop('2020-03-09')
execution = execution.drop('2020-03-09')
data = data.drop('2020-03-17')
slippage = slippage.drop('2020-03-17')
execution = execution.drop('2020-03-17')
returns = pd.DataFrame()
for stock in stocks:
    returns[stock] = np.append(execution[stock][1:].reset_index(drop=True)/execution[stock][:-1].reset_index(drop=True) - 1 , 0)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
#initialising arrays
gross_returns = np.array([])
net_returns = np.array([])
t_s = np.array([])
stock1 = stocks[0]
stock2 = stocks[1]
#moving through the sample
for t in range(window, len(data)-1):
    #defining the unit root function: stock2 = a + b*stock1
    def unit_root(b):
        a = np.average(data[stock2][t-window:t] - b*data[stock1][t-window:t])
        fair_value = a + b*data[stock1][t-window:t]
        diff = np.array(fair_value - data[stock2][t-window:t])
        diff_diff = diff[1:] - diff[:-1]
        reg = sm.OLS(diff_diff, diff[:-1])
        res = reg.fit()
        return res.params[0]/res.bse[0]
    #optimising the cointegration equation parameters
    res1 = spop.minimize(unit_root, data[stock2][t]/data[stock1][t], method='Nelder-Mead')
    t_opt = res1.fun
    b_opt = float(res1.x)
    a_opt = np.average(data[stock2][t-window:t] - b_opt*data[stock1][t-window:t])
    #simulating trading
    fair_value = a_opt + b_opt*data[stock1][t]
    if t == window:
        old_signal = 0
    if t_opt > t_threshold:
        signal = 0
        gross_return = 0
    else:
        signal = np.sign(fair_value - data[stock2][t])
        gross_return = (signal*returns[stock2][t+1]) - (signal*returns[stock1][t+1])
    fees = (fee*abs(signal - old_signal))+(slippage[stock1][t+1]*(signal - old_signal)-slippage[stock2][t+1]*(signal - old_signal))
    net_return = gross_return - fees
    gross_returns = np.append(gross_returns, gross_return)
    net_returns = np.append(net_returns, net_return)
    t_s = np.append(t_s, t_opt)
 #interface: reporting daily positions and realised returns
    print('day '+str(data.index[t]))
    print('')
    if signal == 0:
        print('no trading')
    elif  signal == 1:
        print('long position on '+stock2+' and short position on '+stock1)
    else:
        print('long position on '+stock1+' and short position on '+stock2)
    print('gross daily return: '+str(round(gross_return*100,2))+'%')
    print('net daily return: '+str(round(net_return*100,2))+'%')
    print('cumulative net return so far: '+str(round(np.prod(1+net_returns)*100-100,2))+'%')
    print(signal)
    print('')
    
    old_signal = signal
#plotting equity curves
plt.plot(np.append(1,np.cumprod(1+gross_returns)))
plt.plot(np.append(1,np.cumprod(1+net_returns)))
# Out:
# day 2009-02-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-02-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-02-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-02-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-02 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-03-31 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-02 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-04-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 0.0%
# 0
#
# day 2009-05-05 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.27%
# net daily return: -0.03%
# cumulative net return so far: -0.03%
# 1.0
#
# day 2009-05-06 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.12%
# net daily return: -1.12%
# cumulative net return so far: -1.15%
# 1.0
#
# day 2009-05-07 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.05%
# net daily return: 1.05%
# cumulative net return so far: -0.12%
# 1.0
#
# day 2009-05-08 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.52%
# net daily return: 0.52%
# cumulative net return so far: 0.41%
# 1.0
#
# day 2009-05-11 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.48%
# net daily return: -0.48%
# cumulative net return so far: -0.08%
# 1.0
#
# day 2009-05-12 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.53%
# net daily return: 0.53%
# cumulative net return so far: 0.45%
# 1.0
#
# day 2009-05-13 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.4%
# net daily return: -0.4%
# cumulative net return so far: 0.05%
# 1.0
#
# day 2009-05-14 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.23%
# net daily return: 0.23%
# cumulative net return so far: 0.28%
# 1.0
#
# day 2009-05-15 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.39%
# net daily return: -0.39%
# cumulative net return so far: -0.11%
# 1.0
#
# day 2009-05-18 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.63%
# net daily return: 0.63%
# cumulative net return so far: 0.52%
# 1.0
#
# day 2009-05-19 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.4%
# net daily return: 0.4%
# cumulative net return so far: 0.93%
# 1.0
#
# day 2009-05-20 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.39%
# net daily return: -0.39%
# cumulative net return so far: 0.53%
# 1.0
#
# day 2009-05-21 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.53%
# net daily return: -0.53%
# cumulative net return so far: -0.01%
# 1.0
#
# day 2009-05-22 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.25%
# net daily return: -0.25%
# cumulative net return so far: -0.26%
# 1.0
#
# day 2009-05-26 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.25%
# net daily return: -0.25%
# cumulative net return so far: -0.51%
# 1.0
#
# day 2009-05-27 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.26%
# net daily return: -0.26%
# cumulative net return so far: -0.76%
# 1.0
#
# day 2009-05-28 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.26%
# net daily return: -0.26%
# cumulative net return so far: -1.02%
# 1.0
#
# day 2009-05-29 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.25%
# net daily return: 0.25%
# cumulative net return so far: -0.77%
# 1.0
#
# day 2009-06-01 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.51%
# net daily return: 0.51%
# cumulative net return so far: -0.26%
# 1.0
#
# day 2009-06-02 00:00:00
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.89%
# net daily return: -0.89%
# cumulative net return so far: -1.15%
# 1.0
#
# day 2009-06-03 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.01%
# net daily return: 1.01%
# cumulative net return so far: -0.16%
# 1.0
#
# day 2009-06-04 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.25%
# net daily return: 0.25%
# cumulative net return so far: 0.09%
# 1.0
#
# day 2009-06-05 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.37%
# net daily return: -0.37%
# cumulative net return so far: -0.28%
# 1.0
#
# day 2009-06-08 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.5%
# net daily return: -0.5%
# cumulative net return so far: -0.78%
# 1.0
#
# day 2009-06-09 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.12%
# net daily return: 1.12%
# cumulative net return so far: 0.33%
# 1.0
#
# day 2009-06-10 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.98%
# net daily return: -0.98%
# cumulative net return so far: -0.65%
# 1.0
#
# day 2009-06-11 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.12%
# net daily return: -0.12%
# cumulative net return so far: -0.77%
# 1.0
#
# day 2009-06-12 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.26%
# net daily return: -1.26%
# cumulative net return so far: -2.02%
# 1.0
#
# day 2009-06-16 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.0%
# net daily return: 1.0%
# cumulative net return so far: -1.04%
# 1.0
#
# day 2009-06-17 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.39%
# net daily return: 1.39%
# cumulative net return so far: 0.33%
# 1.0
#
# day 2009-06-18 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.57%
# net daily return: -1.57%
# cumulative net return so far: -1.25%
# 1.0
#
# day 2009-06-19 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.23%
# net daily return: 1.23%
# cumulative net return so far: -0.03%
# 1.0
#
# day 2009-06-23 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.99%
# net daily return: -0.99%
# cumulative net return so far: -1.02%
# 1.0
#
# day 2009-06-24 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.11%
# net daily return: 1.11%
# cumulative net return so far: 0.07%
# 1.0
#
# day 2009-06-25 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.62%
# net daily return: -0.62%
# cumulative net return so far: -0.55%
# 1.0
#
# day 2009-06-26 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.0%
# net daily return: -0.0%
# cumulative net return so far: -0.56%
# 1.0
#
# day 2009-06-30 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.24%
# net daily return: -0.24%
# cumulative net return so far: -0.8%
# 1.0
#
# day 2009-07-01 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: -0.8%
# 1.0
#
# day 2009-07-02 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.61%
# net daily return: 0.61%
# cumulative net return so far: -0.19%
# 1.0
#
# day 2009-07-03 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.24%
# net daily return: -0.24%
# cumulative net return so far: -0.43%
# 1.0
#
# day 2009-07-06 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.72%
# net daily return: -1.72%
# cumulative net return so far: -2.14%
# 1.0
#
# day 2009-07-07 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.35%
# net daily return: 1.35%
# cumulative net return so far: -0.83%
# 1.0
#
# day 2009-07-08 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.04%
# net daily return: -1.04%
# cumulative net return so far: -1.86%
# 1.0
#
# day 2009-07-09 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.77%
# net daily return: 0.77%
# cumulative net return so far: -1.1%
# 1.0
#
# day 2009-07-10 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.27%
# net daily return: 0.27%
# cumulative net return so far: -0.84%
# 1.0
#
# day 2009-07-13 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.92%
# net daily return: 0.92%
# cumulative net return so far: 0.07%
# 1.0
#
# day 2009-07-14 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.26%
# net daily return: -0.26%
# cumulative net return so far: -0.19%
# 1.0
#
# day 2009-07-15 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.26%
# net daily return: -0.63%
# cumulative net return so far: -0.81%
# -1.0
#
# day 2009-07-16 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 1.05%
# net daily return: 1.05%
# cumulative net return so far: 0.23%
# -1.0
#
# day 2009-07-17 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.9%
# net daily return: -0.9%
# cumulative net return so far: -0.67%
# -1.0
#
# day 2009-07-21 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.12%
# net daily return: -0.59%
# cumulative net return so far: -1.26%
# 1.0
#
# day 2009-07-22 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.39%
# net daily return: -0.39%
# cumulative net return so far: -1.64%
# 1.0
#
# day 2009-07-23 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.87%
# net daily return: -0.87%
# cumulative net return so far: -2.5%
# 1.0
#
# day 2009-07-27 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.75%
# net daily return: 0.75%
# cumulative net return so far: -1.76%
# 1.0
#
# day 2009-07-28 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.01%
# net daily return: -0.01%
# cumulative net return so far: -1.77%
# 1.0
#
# day 2009-07-29 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.37%
# net daily return: -0.37%
# cumulative net return so far: -2.13%
# 1.0
#
# day 2009-07-30 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.37%
# net daily return: 0.37%
# cumulative net return so far: -1.78%
# 1.0
#
# day 2009-07-31 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.73%
# net daily return: -0.73%
# cumulative net return so far: -2.49%
# 1.0
#
# day 2009-08-03 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.24%
# net daily return: 0.24%
# cumulative net return so far: -2.26%
# 1.0
#
# day 2009-08-04 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.12%
# net daily return: 0.12%
# cumulative net return so far: -2.14%
# 1.0
#
# day 2009-08-05 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.71%
# net daily return: 0.71%
# cumulative net return so far: -1.45%
# 1.0
#
# day 2009-08-06 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.34%
# net daily return: -0.34%
# cumulative net return so far: -1.78%
# 1.0
#
# day 2009-08-10 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.11%
# net daily return: 0.11%
# cumulative net return so far: -1.67%
# 1.0
#
# day 2009-08-11 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.36%
# net daily return: -0.36%
# cumulative net return so far: -2.02%
# 1.0
#
# day 2009-08-12 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.23%
# net daily return: -0.23%
# cumulative net return so far: -2.25%
# 1.0
#
# day 2009-08-13 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.02%
# net daily return: 1.02%
# cumulative net return so far: -1.25%
# 1.0
# day 2009-08-14 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.8%
# net daily return: -0.8%
# cumulative net return so far: -2.04%
# 1.0
#
# day 2009-08-18 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.69%
# net daily return: 0.69%
# cumulative net return so far: -1.37%
# 1.0
#
# day 2009-08-19 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.35%
# net daily return: -0.35%
# cumulative net return so far: -1.71%
# 1.0
#
# day 2009-08-20 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.12%
# net daily return: -0.12%
# cumulative net return so far: -1.83%
# 1.0
#
# day 2009-08-21 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.84%
# net daily return: 1.84%
# cumulative net return so far: -0.02%
# 1.0
#
# day 2009-08-24 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.39%
# net daily return: -1.39%
# cumulative net return so far: -1.41%
# 1.0
#
# day 2009-08-25 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.63%
# net daily return: 0.09%
# cumulative net return so far: -1.32%
# -1.0
#
# day 2009-08-26 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.32%
# net daily return: 0.98%
# cumulative net return so far: -0.35%
# 1.0
#
# day 2009-08-27 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.85%
# net daily return: -1.85%
# cumulative net return so far: -2.19%
# 1.0
#
# day 2009-08-28 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.98%
# net daily return: -1.66%
# cumulative net return so far: -3.82%
# -1.0
#
# day 2009-08-31 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.44%
# net daily return: -0.89%
# cumulative net return so far: -4.67%
# 1.0
#
# day 2009-09-01 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: -4.67%
# 1.0
#
# day 2009-09-02 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.8%
# net daily return: 0.8%
# cumulative net return so far: -3.9%
# 1.0
#
# day 2009-09-03 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.46%
# net daily return: -0.46%
# cumulative net return so far: -4.35%
# 1.0
#
# day 2009-09-04 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.33%
# net daily return: 0.33%
# cumulative net return so far: -4.03%
# 1.0
#
# day 2009-09-07 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.55%
# net daily return: 0.55%
# cumulative net return so far: -3.51%
# 1.0
#
# day 2009-09-08 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.33%
# net daily return: 0.33%
# cumulative net return so far: -3.19%
# 1.0
#
# day 2009-09-09 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.32%
# net daily return: -1.32%
# cumulative net return so far: -4.47%
# 1.0
#
# day 2009-09-10 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.55%
# net daily return: -0.06%
# cumulative net return so far: -4.53%
# -1.0
#
# day 2009-09-11 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.77%
# net daily return: 0.49%
# cumulative net return so far: -4.06%
# 1.0
#
# day 2009-09-14 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.21%
# net daily return: 0.21%
# cumulative net return so far: -3.86%
# 1.0
#
# day 2009-09-15 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.32%
# net daily return: 0.32%
# cumulative net return so far: -3.55%
# 1.0
#
# day 2009-09-16 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -2.15%
# net daily return: -2.15%
# cumulative net return so far: -5.63%
# 1.0
#
# day 2009-09-17 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.23%
# net daily return: 1.23%
# cumulative net return so far: -4.47%
# 1.0
#
# day 2009-09-18 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.21%
# net daily return: 0.21%
# cumulative net return so far: -4.27%
# 1.0
#
# day 2009-09-21 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.83%
# net daily return: 0.83%
# cumulative net return so far: -3.47%
# 1.0
#
# day 2009-09-22 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.64%
# net daily return: -1.64%
# cumulative net return so far: -5.06%
# 1.0
#
# day 2009-09-23 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 2.28%
# net daily return: 2.28%
# cumulative net return so far: -2.89%
# 1.0
#
# day 2009-09-24 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.8%
# net daily return: -0.8%
# cumulative net return so far: -3.67%
# 1.0
#
# day 2009-09-25 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 1.0%
# net daily return: 0.54%
# cumulative net return so far: -3.14%
# -1.0
#
# day 2009-09-28 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.89%
# net daily return: 0.52%
# cumulative net return so far: -2.64%
# 1.0
#
# day 2009-09-29 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.67%
# net daily return: -0.67%
# cumulative net return so far: -3.29%
# 1.0
#
# day 2009-09-30 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.1%
# net daily return: -0.1%
# cumulative net return so far: -3.39%
# 1.0
#
# day 2009-10-01 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.09%
# net daily return: 1.09%
# cumulative net return so far: -2.34%
# 1.0
#
# day 2009-10-02 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.67%
# net daily return: -1.67%
# cumulative net return so far: -3.97%
# 1.0
#
# day 2009-10-05 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -1.06%
# net daily return: -1.79%
# cumulative net return so far: -5.69%
# -1.0
#
# day 2009-10-06 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.96%
# net daily return: -1.55%
# cumulative net return so far: -7.15%
# 1.0
#
# day 2009-10-07 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.2%
# net daily return: -0.2%
# cumulative net return so far: -7.34%
# 1.0
#
# day 2009-10-08 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.79%
# net daily return: 0.79%
# cumulative net return so far: -6.61%
# 1.0
#
# day 2009-10-09 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.11%
# net daily return: -1.11%
# cumulative net return so far: -7.64%
# 1.0
#
# day 2009-10-13 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.32%
# net daily return: 1.32%
# cumulative net return so far: -6.42%
# 1.0
#
# day 2009-10-14 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.61%
# net daily return: -0.61%
# cumulative net return so far: -6.99%
# 1.0
#
# day 2009-10-15 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.45%
# net daily return: 1.45%
# cumulative net return so far: -5.65%
# 1.0
#
# day 2009-10-16 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.8%
# net daily return: -0.8%
# cumulative net return so far: -6.4%
# 1.0
#
# day 2009-10-19 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.99%
# net daily return: -1.76%
# cumulative net return so far: -8.05%
# -1.0
#
# day 2009-10-20 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.39%
# net daily return: -1.98%
# cumulative net return so far: -9.87%
# 1.0
#
# day 2009-10-21 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.89%
# net daily return: -1.54%
# cumulative net return so far: -11.26%
# -1.0
#
# day 2009-10-22 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.19%
# net daily return: -0.66%
# cumulative net return so far: -11.84%
# 1.0
# day 2009-10-23 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.48%
# net daily return: -0.09%
# cumulative net return so far: -11.92%
# -1.0
#
# day 2009-10-26 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.0%
# net daily return: -0.36%
# cumulative net return so far: -12.24%
# 1.0
#
# day 2009-10-27 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.8%
# net daily return: 0.8%
# cumulative net return so far: -11.54%
# 1.0
#
# day 2009-10-28 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.06%
# net daily return: -0.06%
# cumulative net return so far: -11.59%
# 1.0
#
# day 2009-10-29 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.01%
# net daily return: -0.42%
# cumulative net return so far: -11.96%
# -1.0
#
# day 2009-10-30 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.08%
# net daily return: -0.08%
# cumulative net return so far: -12.03%
# -1.0
#
# day 2009-11-03 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.13%
# net daily return: 0.13%
# cumulative net return so far: -11.92%
# -1.0
#
# day 2009-11-04 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.69%
# net daily return: 0.69%
# cumulative net return so far: -11.32%
# -1.0
#
# day 2009-11-05 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -1.18%
# net daily return: -1.18%
# cumulative net return so far: -12.36%
# -1.0
#
# day 2009-11-06 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.2%
# net daily return: -0.72%
# cumulative net return so far: -12.99%
# 1.0
#
# day 2009-11-09 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.09%
# net daily return: -0.49%
# cumulative net return so far: -13.42%
# -1.0
#
# day 2009-11-10 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.78%
# net daily return: 0.78%
# cumulative net return so far: -12.74%
# -1.0
#
# day 2009-11-11 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.1%
# net daily return: 0.1%
# cumulative net return so far: -12.66%
# -1.0
#
# day 2009-11-12 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.77%
# net daily return: 0.39%
# cumulative net return so far: -12.31%
# 1.0
#
# day 2009-11-13 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.87%
# net daily return: 0.87%
# cumulative net return so far: -11.55%
# 1.0
#
# day 2009-11-17 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.02%
# net daily return: -0.41%
# cumulative net return so far: -11.91%
# -1.0
#
# day 2009-11-18 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.58%
# net daily return: 0.58%
# cumulative net return so far: -11.41%
# -1.0
#
# day 2009-11-19 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.48%
# net daily return: 0.48%
# cumulative net return so far: -10.98%
# -1.0
#
# day 2009-11-20 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.19%
# net daily return: 0.19%
# cumulative net return so far: -10.81%
# -1.0
#
# day 2009-11-23 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.2%
# net daily return: -0.8%
# cumulative net return so far: -11.53%
# 1.0
#
# day 2009-11-24 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.86%
# net daily return: 1.86%
# cumulative net return so far: -9.88%
# 1.0
#
# day 2009-11-25 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.82%
# net daily return: -1.82%
# cumulative net return so far: -11.52%
# 1.0
#
# day 2009-11-26 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 1.02%
# net daily return: 0.42%
# cumulative net return so far: -11.15%
# -1.0
#
# day 2009-11-27 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.29%
# net daily return: 0.02%
# cumulative net return so far: -11.13%
# 1.0
#
# day 2009-11-30 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.73%
# net daily return: 0.73%
# cumulative net return so far: -10.48%
# 1.0
#
# day 2009-12-01 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.0%
# net daily return: -1.0%
# cumulative net return so far: -11.38%
# 1.0
#
# day 2009-12-02 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.44%
# net daily return: 0.44%
# cumulative net return so far: -10.99%
# 1.0
#
# day 2009-12-03 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.09%
# net daily return: -0.09%
# cumulative net return so far: -11.07%
# 1.0
#
# day 2009-12-04 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: -11.07%
# 1.0
#
# day 2009-12-07 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.53%
# net daily return: 0.53%
# cumulative net return so far: -10.6%
# 1.0
#
# day 2009-12-09 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.97%
# net daily return: -0.97%
# cumulative net return so far: -11.47%
# 1.0
#
# day 2009-12-10 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.08%
# net daily return: -0.08%
# cumulative net return so far: -11.54%
# 1.0
#
# day 2009-12-11 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.26%
# net daily return: 0.26%
# cumulative net return so far: -11.31%
# 1.0
#
# day 2009-12-14 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.32%
# net daily return: 1.32%
# cumulative net return so far: -10.14%
# 1.0
#
# day 2009-12-15 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.85%
# net daily return: 0.85%
# cumulative net return so far: -9.38%
# 1.0
#
# day 2009-12-16 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.45%
# net daily return: 0.13%
# cumulative net return so far: -9.26%
# -1.0
#
# day 2009-12-17 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.9%
# net daily return: 0.9%
# cumulative net return so far: -8.44%
# -1.0
#
# day 2009-12-18 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.27%
# net daily return: -1.88%
# cumulative net return so far: -10.16%
# 1.0
#
# day 2009-12-21 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.69%
# net daily return: 0.69%
# cumulative net return so far: -9.55%
# 1.0
#
# day 2009-12-22 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.86%
# net daily return: 0.86%
# cumulative net return so far: -8.77%
# 1.0
#
# day 2009-12-23 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.48%
# net daily return: -1.48%
# cumulative net return so far: -10.12%
# 1.0
#
# day 2009-12-24 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: -10.12%
# 1.0
#
# day 2009-12-25 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.69%
# net daily return: 0.69%
# cumulative net return so far: -9.5%
# 1.0
#
# day 2009-12-28 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.96%
# net daily return: 0.96%
# cumulative net return so far: -8.64%
# 1.0
#
# day 2009-12-29 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.23%
# net daily return: -1.23%
# cumulative net return so far: -9.76%
# 1.0
#
# day 2009-12-30 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: -9.76%
# 1.0
#
# day 2010-01-01 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.34%
# net daily return: 0.34%
# cumulative net return so far: -9.45%
# 1.0
# day 2010-01-04 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.7%
# net daily return: 0.7%
# cumulative net return so far: -8.82%
# 1.0
#
# day 2010-01-05 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.43%
# net daily return: -0.43%
# cumulative net return so far: -9.21%
# 1.0
#
# day 2010-01-07 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.36%
# net daily return: 0.36%
# cumulative net return so far: -8.89%
# 1.0
#
# day 2010-01-08 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.26%
# net daily return: -0.26%
# cumulative net return so far: -9.13%
# 1.0
#
# day 2010-01-12 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.18%
# net daily return: -0.18%
# cumulative net return so far: -9.29%
# 1.0
#
# day 2010-01-13 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.18%
# net daily return: 0.18%
# cumulative net return so far: -9.13%
# 1.0
#
# day 2010-01-14 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.62%
# net daily return: 1.62%
# cumulative net return so far: -7.66%
# 1.0
#
# day 2010-01-15 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 1.43%
# net daily return: 1.37%
# cumulative net return so far: -6.4%
# -1.0
#
# day 2010-01-18 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.44%
# net daily return: -0.12%
# cumulative net return so far: -6.5%
# 1.0
#
# day 2010-01-19 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.89%
# net daily return: 0.65%
# cumulative net return so far: -5.89%
# -1.0
#
# day 2010-01-20 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.89%
# net daily return: -1.52%
# cumulative net return so far: -7.32%
# 1.0
#
# day 2010-01-21 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.37%
# net daily return: 0.37%
# cumulative net return so far: -6.98%
# 1.0
#
# day 2010-01-22 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.17%
# net daily return: 0.17%
# cumulative net return so far: -6.82%
# 1.0
#
# day 2010-01-25 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.36%
# net daily return: 0.36%
# cumulative net return so far: -6.48%
# 1.0
#
# day 2010-01-26 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.54%
# net daily return: -0.54%
# cumulative net return so far: -6.99%
# 1.0
#
# day 2010-01-27 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.28%
# net daily return: 0.28%
# cumulative net return so far: -6.73%
# 1.0
#
# day 2010-01-28 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.85%
# net daily return: -1.85%
# cumulative net return so far: -8.45%
# 1.0
#
# day 2010-01-29 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.99%
# net daily return: 1.99%
# cumulative net return so far: -6.63%
# 1.0
#
# day 2010-02-01 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.27%
# net daily return: 0.27%
# cumulative net return so far: -6.38%
# 1.0
#
# day 2010-02-02 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -2.54%
# net daily return: -2.54%
# cumulative net return so far: -8.75%
# 1.0
#
# day 2010-02-03 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.86%
# net daily return: 0.86%
# cumulative net return so far: -7.97%
# 1.0
#
# day 2010-02-05 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.12%
# net daily return: 1.12%
# cumulative net return so far: -6.93%
# 1.0
#
# day 2010-02-08 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.68%
# net daily return: 0.68%
# cumulative net return so far: -6.31%
# 1.0
#
# day 2010-02-09 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.09%
# net daily return: 0.09%
# cumulative net return so far: -6.22%
# 1.0
#
# day 2010-02-10 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.0%
# net daily return: 0.0%
# cumulative net return so far: -6.22%
# 1.0
#
# day 2010-02-11 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.56%
# net daily return: -0.56%
# cumulative net return so far: -6.74%
# 1.0
#
# day 2010-02-12 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.38%
# net daily return: 0.38%
# cumulative net return so far: -6.39%
# 1.0
#
# day 2010-02-15 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.28%
# net daily return: 0.28%
# cumulative net return so far: -6.13%
# 1.0
#
# day 2010-02-16 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.65%
# net daily return: 0.31%
# cumulative net return so far: -5.84%
# -1.0
#
# day 2010-02-17 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.56%
# net daily return: 0.33%
# cumulative net return so far: -5.54%
# 1.0
#
# day 2010-02-18 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.73%
# net daily return: 0.4%
# cumulative net return so far: -5.16%
# -1.0
#
# day 2010-02-22 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.27%
# net daily return: -0.15%
# cumulative net return so far: -5.3%
# 1.0
#
# day 2010-02-23 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.64%
# net daily return: -0.64%
# cumulative net return so far: -5.91%
# 1.0
#
# day 2010-02-24 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.98%
# net daily return: 0.98%
# cumulative net return so far: -4.99%
# 1.0
#
# day 2010-02-25 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.73%
# net daily return: -0.73%
# cumulative net return so far: -5.68%
# 1.0
#
# day 2010-02-26 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.18%
# net daily return: 0.18%
# cumulative net return so far: -5.51%
# 1.0
#
# day 2010-03-01 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.98%
# net daily return: 0.98%
# cumulative net return so far: -4.59%
# 1.0
#
# day 2010-03-02 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.73%
# net daily return: 0.39%
# cumulative net return so far: -4.22%
# -1.0
#
# day 2010-03-03 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.0%
# net daily return: -0.59%
# cumulative net return so far: -4.78%
# 1.0
#
# day 2010-03-04 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.09%
# net daily return: -0.09%
# cumulative net return so far: -4.87%
# 1.0
#
# day 2010-03-05 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.09%
# net daily return: -0.09%
# cumulative net return so far: -4.95%
# 1.0
#
# day 2010-03-08 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -1.62%
# net daily return: -1.62%
# cumulative net return so far: -6.49%
# 1.0
#
# day 2010-03-09 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 2.43%
# net daily return: 2.43%
# cumulative net return so far: -4.22%
# 1.0
#
# day 2010-03-10 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.37%
# net daily return: 0.37%
# cumulative net return so far: -3.87%
# 1.0
#
# day 2010-03-11 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.47%
# net daily return: -0.47%
# cumulative net return so far: -4.32%
# 1.0
#
# day 2010-03-12 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.09%
# net daily return: -0.67%
# cumulative net return so far: -4.96%
# -1.0
#
# day 2010-03-15 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.73%
# net daily return: 0.73%
# cumulative net return so far: -4.27%
# -1.0
#
# day 2010-03-16 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.37%
# net daily return: 0.08%
# cumulative net return so far: -4.19%
# 1.0
#
# day 2010-03-17 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.36%
# net daily return: -0.36%
# cumulative net return so far: -4.53%
# 1.0
#
# day 2010-03-18 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.09%
# net daily return: 0.09%
# cumulative net return so far: -4.45%
# 1.0
# day 2010-03-19 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: -0.74%
# net daily return: -0.74%
# cumulative net return so far: -5.15%
# 1.0
#
# day 2010-03-23 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.09%
# net daily return: 0.09%
# cumulative net return so far: -5.07%
# 1.0
#
# day 2010-03-24 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 1.09%
# net daily return: 1.09%
# cumulative net return so far: -4.03%
# 1.0
#
# day 2010-03-25 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.46%
# net daily return: -0.06%
# cumulative net return so far: -4.09%
# -1.0
#
# day 2010-03-26 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.64%
# net daily return: 0.17%
# cumulative net return so far: -3.93%
# 1.0
#
# day 2010-03-29 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 1.27%
# net daily return: 1.08%
# cumulative net return so far: -2.88%
# -1.0
#
# day 2010-03-30 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.55%
# net daily return: 0.23%
# cumulative net return so far: -2.66%
# 1.0
#
# day 2010-03-31 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.36%
# net daily return: 0.36%
# cumulative net return so far: -2.31%
# 1.0
#
# day 2010-04-05 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.27%
# net daily return: -0.89%
# cumulative net return so far: -3.18%
# -1.0
#
# day 2010-04-06 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.19%
# net daily return: 0.19%
# cumulative net return so far: -3.0%
# -1.0
#
# day 2010-04-07 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.25%
# net daily return: -0.25%
# cumulative net return so far: -3.25%
# -1.0
#
# day 2010-04-08 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.68%
# net daily return: 0.68%
# cumulative net return so far: -2.59%
# -1.0
#
# day 2010-04-09 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.78%
# net daily return: -0.78%
# cumulative net return so far: -3.35%
# -1.0
#
# day 2010-04-12 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.53%
# net daily return: 0.53%
# cumulative net return so far: -2.84%
# -1.0
#
# day 2010-04-13 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.17%
# net daily return: -0.24%
# cumulative net return so far: -3.07%
# 1.0
#
# day 2010-04-14 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.25%
# net daily return: -1.3%
# cumulative net return so far: -4.33%
# -1.0
#
# day 2010-04-15 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.32%
# net daily return: 0.32%
# cumulative net return so far: -4.02%
# -1.0
#
# day 2010-04-16 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.77%
# net daily return: 0.77%
# cumulative net return so far: -3.29%
# -1.0
#
# day 2010-04-19 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.61%
# net daily return: 0.52%
# cumulative net return so far: -2.79%
# 1.0
#
# day 2010-04-20 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.34%
# net daily return: 0.34%
# cumulative net return so far: -2.46%
# 1.0
#
# day 2010-04-21 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.09%
# net daily return: -0.33%
# cumulative net return so far: -2.77%
# -1.0
#
# day 2010-04-22 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: 0.35%
# net daily return: 0.35%
# cumulative net return so far: -2.44%
# -1.0
#
# day 2010-04-23 00:00:00
#
# long position on PFBCOLOM.CL and short position on BCOLOMBIA.CL
# gross daily return: 0.34%
# net daily return: 0.03%
# cumulative net return so far: -2.41%
# 1.0
#
# day 2010-04-26 00:00:00
#
# long position on BCOLOMBIA.CL and short position on PFBCOLOM.CL
# gross daily return: -0.35%
# net daily return: -0.79%
# ...
# 0
#
# day 2022-08-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-08-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-08-25 00:00:00
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-08-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-08-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-08-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-08-31 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-02 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-09-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-10-31 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-02 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-11-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
# day 2022-12-02 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-28 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-29 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2022-12-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-02 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-04 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-05 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-11 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-12 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-18 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-19 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-23 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-24 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-25 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-26 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-27 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-30 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-01-31 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-01 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-02 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-03 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-06 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-07 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-08 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-09 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-10 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-13 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-14 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-15 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-16 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-17 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-20 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-21 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0
#
# day 2023-02-22 00:00:00
#
# no trading
# gross daily return: 0%
# net daily return: 0.0%
# cumulative net return so far: 174.97%
# 0

# %%
print('mean: '+str(round(np.mean(net_returns),4)))
print('standard deviation: '+str(round(np.std(net_returns),4)))
print('CAGR: '+str(round((np.prod(1+net_returns)**(1/15))-1,4)))
# Out:
# mean: 0.0003
# standard deviation: 0.0098
# CAGR: 0.0698

# %%
spread = pd.DataFrame()
spread =  (fair_value-data[stock1][:t])
spread.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
meanspread = spread.mean()
stdspread = np.std(spread)
nspread = pd.DataFrame()
nspread = (spread-meanspread)/stdspread

# %%
nspread.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
spread2 = pd.DataFrame()
spread2 = data[stock2][:t] - data[stock1][:t]
spread2.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
